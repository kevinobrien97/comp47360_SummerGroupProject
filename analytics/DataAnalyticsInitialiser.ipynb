# %% [markdown]
# To open this with SSH tunnelling, connect to the UCD High Performance server, choose a port to work on (I used 1234), and enter:
# - jupyter notebook --no-browser --port 1234
#
# Open a new terminal window and enter:
# - ssh -NL 1234:localhost:1234 team9@telemachus.ucd.ie
#
# and then enter the server password.
#
# I was then able to open the jupyter notebook homepage using the second link that was generated on the HP server when I started the notebook and pasting that into my browser.
#
# For more info see: https://medium.com/@apbetahouse45/how-to-run-jupyter-notebooks-on-remote-server-part-1-ssh-a2be0232c533

# %%
ls
# Out:
# 'Data Analytics Initialiser.ipynb'   miniconda3/
#  datafile.tar.gz                     Miniconda3-latest-Linux-x86_64.sh*
#  git_environment/                    tmp/

# %%
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [2], in <cell line: 1>()
# ----> 1 import pandas as pd
#
# ModuleNotFoundError: No module named 'pandas'

# %%
# !pip install pandas
# Out:
# ...
#      |████████████████████████████████| 11.7 MB 13.2 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 16.8 MB 54.8 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 503 kB 23.0 MB/s eta 0:00:01
# ...

# %%
import pandas as pd

# %%
cd tmp
# Out:
# /home/team9/tmp

# %%
ls
# Out:
# data/

# %%
cd data
# Out:
# /home/team9/tmp/data

# %%
ls
# Out:
# rt_leavetimes_DB_2018.txt  rt_vehicles_DB_2018.txt
# rt_trips_DB_2018.txt       rt_vehicles_DB_2018.zip

# %% [markdown]
# Specifying nrows as file is too large otherwise

# %%
leaveTimes = pd.read_csv('rt_leavetimes_DB_2018.txt', sep=";", nrows=100)

# %%
leaveTimes
# Out:
#    DATASOURCE        DAYOFSERVICE   TRIPID  PROGRNUMBER  STOPPOINTID  \
# 0          DB  01-JAN-18 00:00:00  5972116           12          119
# 1          DB  01-JAN-18 00:00:00  5966674           12          119
# 2          DB  01-JAN-18 00:00:00  5959105           12          119
# 3          DB  01-JAN-18 00:00:00  5966888           12          119
# 4          DB  01-JAN-18 00:00:00  5965960           12          119
# ..        ...                 ...      ...          ...          ...
# 95         DB  01-JAN-18 00:00:00  5968829           66         4663
# 96         DB  01-JAN-18 00:00:00  5965484           66         4663
# 97         DB  01-JAN-18 00:00:00  5958689           66         4663
# 98         DB  01-JAN-18 00:00:00  5964048           66         4663
# 99         DB  01-JAN-18 00:00:00  5965482           66         4663
#
#     PLANNEDTIME_ARR  PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP  \
# ...

# %%
trips = pd.read_csv('rt_trips_DB_2018.txt', sep=";", nrows=100)
trips
# Out:
#    DATASOURCE        DAYOFSERVICE   TRIPID LINEID  ROUTEID  DIRECTION  \
# 0          DB  07-FEB-18 00:00:00  6253783     68    68_80          1
# 1          DB  07-FEB-18 00:00:00  6262138    25B  25B_271          2
# 2          DB  07-FEB-18 00:00:00  6254942    45A   45A_70          2
# 3          DB  07-FEB-18 00:00:00  6259460    25A  25A_273          1
# 4          DB  07-FEB-18 00:00:00  6253175     14    14_15          1
# ..        ...                 ...      ...    ...      ...        ...
# 95         DB  18-FEB-18 00:00:00  6268684    46A   46A_67          2
# 96         DB  18-FEB-18 00:00:00  6277164     31    31_18          2
# 97         DB  18-FEB-18 00:00:00  6271460     31    31_18          2
# 98         DB  18-FEB-18 00:00:00  6276481     14    14_16          2
# 99         DB  18-FEB-18 00:00:00  6270708     14    14_16          2
#
#     PLANNEDTIME_ARR  PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP   BASIN  \
# ...

# %%
vehicles = pd.read_csv('rt_vehicles_DB_2018.txt', sep=";", nrows=100)
vehicles
# Out:
#    DATASOURCE        DAYOFSERVICE  VEHICLEID  DISTANCE  MINUTES  \
# 0          DB  23-NOV-18 00:00:00    3303848    286166    58849
# 1          DB  23-NOV-18 00:00:00    3303847    259545    56828
# 2          DB  28-FEB-18 00:00:00    2868329    103096    40967
# 3          DB  28-FEB-18 00:00:00    2868330    147277    43599
# 4          DB  28-FEB-18 00:00:00    2868331    224682    40447
# ..        ...                 ...        ...       ...      ...
# 95         DB  22-JUN-18 00:00:00    2868341    271579    55676
# 96         DB  22-JUN-18 00:00:00    2868342    280097    66080
# 97         DB  22-JUN-18 00:00:00    2868343    251644    45142
# 98         DB  22-JUN-18 00:00:00    2868344    198033    51354
# 99         DB  22-JUN-18 00:00:00    2868345    220367    59893
#
#             LASTUPDATE  NOTE
# 0   04-DEC-18 08:03:09   NaN
# 1   04-DEC-18 08:03:09   NaN
# 2   08-MAR-18 10:35:59   NaN
# 3   08-MAR-18 10:35:59   NaN
# 4   08-MAR-18 10:35:59   NaN
# ...

# %% [markdown]
# We should not store our files on the server apparently as they are liable to be lost. Therefore we can download them once we are finished working and upload to Github. I found the below way worked for me but there may be a better solution as mine is quite convoluted. Enter the below into a terminal window:
# - scp team9@telemachus.ucd.ie:DataAnalyticsInitialiser.ipynb ~
#
# This saves a version of this file to your root directory. Go to this directory and move the file into the analytics folder on your repo and replace the version there - then push to Github.
